# %% [markdown]
# # Looking at the Qiskit Workflow

# %% [markdown]
# Hello World Two Qubit Example

# %% [markdown]
# Step One: Imports

# %%
import qiskit
from qiskit import QuantumCircuit
from qiskit.quantum_info import Pauli
from qiskit_aer.primitives import Estimator
import matplotlib.pyplot as plt

# %%
from qiskit import QuantumCircuit
from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2 as Sampler
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit.visualization import plot_bloch_multivector, plot_histogram

import matplotlib.pyplot as plt

# %% [markdown]
# Map The Problem

# %%
qc = QuantumCircuit(2)

qc.h(0)
qc.cx(0,1)

qc.draw(output='mpl')

# %% [markdown]
# Step Two: Observables

# %%
ZZ = Pauli("ZZ")
ZI = Pauli('ZI')
IZ = Pauli('IZ')
XX = Pauli('XX')
XI = Pauli('XI')
IX = Pauli('IX')

observables = [ZZ, ZI, IZ,XX, XI, IX]

# %% [markdown]
# Step Three: Optimizing Circuit

# %% [markdown]
# Step Four: Execute

# %%
estimator = Estimator()
job = estimator.run([qc] * len(observables), observables)

job.result()
# Out:
# EstimatorResult(values=array([ 1.        , -0.01171875, -0.01171875,  1.        ,  0.00585938,
#         0.00585938]), metadata=[{'shots': 1024, 'variance': 0.0, 'simulator_metadata': [{'batched_shots_optimization': False, 'required_memory_mb': 0, 'method': 'stabilizer', 'active_input_qubits': [0, 1], 'device': 'CPU', 'remapped_qubits': False, 'num_qubits': 2, 'num_clbits': 2, 'time_taken': 0.0058472, 'sample_measure_time': 0.001434, 'input_qubit_map': [[0, 0], [1, 1]], 'max_memory_mb': 16151, 'measure_sampling': True, 'noise': 'ideal', 'parallel_shots': 1, 'parallel_state_update': 8, 'runtime_parameter_bind': False, 'num_bind_params': 1, 'fusion': {'enabled': False}}]}, {'shots': 1024, 'variance': 0.9998626708984375, 'simulator_metadata': [{'batched_shots_optimization': False, 'required_memory_mb': 0, 'method': 'stabilizer', 'active_input_qubits': [0, 1], 'device': 'CPU', 'remapped_qubits': False, 'num_qubits': 2, 'num_clbits': 2, 'time_taken': 0.0058472, 'sample_measure_time': 0.001434, 'input_qubit_map': [[0, 0], [1, 1]], 'max_memory_mb': 16151, 'measure_sampling': True, 'noise': 'ideal', 'parallel_shots': 1, 'parallel_state_update': 8, 'runtime_parameter_bind': False, 'num_bind_params': 1, 'fusion': {'enabled': False}}]}, {'shots': 1024, 'variance': 0.9998626708984375, 'simulator_metadata': [{'batched_shots_optimization': False, 'required_memory_mb': 0, 'method': 'stabilizer', 'active_input_qubits': [0, 1], 'device': 'CPU', 'remapped_qubits': False, 'num_qubits': 2, 'num_clbits': 2, 'time_taken': 0.0058472, 'sample_measure_time': 0.001434, 'input_qubit_map': [[0, 0], [1, 1]], 'max_memory_mb': 16151, 'measure_sampling': True, 'noise': 'ideal', 'parallel_shots': 1, 'parallel_state_update': 8, 'runtime_parameter_bind': False, 'num_bind_params': 1, 'fusion': {'enabled': False}}]}, {'shots': 1024, 'variance': 0.0, 'simulator_metadata': [{'batched_shots_optimization': False, 'required_memory_mb': 0, 'method': 'stabilizer', 'active_input_qubits': [0, 1], 'device': 'CPU', 'remapped_qubits': False, 'num_qubits': 2, 'num_clbits': 2, 'time_taken': 0.0053536, 'sample_measure_time': 0.0025166, 'input_qubit_map': [[0, 0], [1, 1]], 'max_memory_mb': 16151, 'measure_sampling': True, 'noise': 'ideal', 'parallel_shots': 1, 'parallel_state_update': 8, 'runtime_parameter_bind': False, 'num_bind_params': 1, 'fusion': {'enabled': False}}]}, {'shots': 1024, 'variance': 0.9999656677246094, 'simulator_metadata': [{'batched_shots_optimization': False, 'required_memory_mb': 0, 'method': 'stabilizer', 'active_input_qubits': [0, 1], 'device': 'CPU', 'remapped_qubits': False, 'num_qubits': 2, 'num_clbits': 2, 'time_taken': 0.0053536, 'sample_measure_time': 0.0025166, 'input_qubit_map': [[0, 0], [1, 1]], 'max_memory_mb': 16151, 'measure_sampling': True, 'noise': 'ideal', 'parallel_shots': 1, 'parallel_state_update': 8, 'runtime_parameter_bind': False, 'num_bind_params': 1, 'fusion': {'enabled': False}}]}, {'shots': 1024, 'variance': 0.9999656677246094, 'simulator_metadata': [{'batched_shots_optimization': False, 'required_memory_mb': 0, 'method': 'stabilizer', 'active_input_qubits': [0, 1], 'device': 'CPU', 'remapped_qubits': False, 'num_qubits': 2, 'num_clbits': 2, 'time_taken': 0.0053536, 'sample_measure_time': 0.0025166, 'input_qubit_map': [[0, 0], [1, 1]], 'max_memory_mb': 16151, 'measure_sampling': True, 'noise': 'ideal', 'parallel_shots': 1, 'parallel_state_update': 8, 'runtime_parameter_bind': False, 'num_bind_params': 1, 'fusion': {'enabled': False}}]}])

# %% [markdown]
# Step Five: Post-process(and plotting)

# %%
data = ['ZZ',"ZI","IZ","XX","XI","IX"]
values = job.result().values

plt.plot(data, values, '-o' )
plt.xlabel("observables")
plt.ylabel('Expectation Value')
# Out:
# Text(0, 0.5, 'Expectation Value')

# %% [markdown]
# N-quibt Example

# %% [markdown]
# Step
